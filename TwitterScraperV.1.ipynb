# %%
import json
from argparse import ArgumentParser
import requests
from pymongo import MongoClient
from pymongo.errors import ConnectionFailure
from bson import json_util, ObjectId
import couchdb
import tweepy

# %%
###API ########################
ckey = "BZDRUfaXo49Sd77rundshFaeO"
csecret = "GaJ59gqr9xHuwg8aBDs9sfdEiIfLMno6zSp53SL5FEOEkls8rl"
atoken = "1485635032844746757-4iQH0YAccGKQpYH9KPYUyJ42FDQBuP"
asecret = "hlSbkJmqS27A81QWELhpEVT1pm9BVUTx0lRAxv9uNPVTW"
#####################################

# %%
class listener(tweepy.Stream):
    
    def on_data(self, data):
        dictTweet = json.loads(data)
        try:
            
            dictTweet["_id"] = str(dictTweet['id'])
            doc = db.save(dictTweet)
            print ("SAVED" + str(doc) +"=>" + str(data))
        except:
            print ("Already exists")
            pass
        return True
    
    def on_error(self, status):
        print (status)

# %%
twitter_stream = listener(ckey, csecret,atoken,asecret)
server = couchdb.Server('http://adrian:adrian@localhost:5984/')  #('http://115.146.93.184:5984/')
try:
    db = server.create('loc2')
except:
    db = server['loc2']

# %%
twitter_stream.filter(locations=[-78.619545,-0.365889,-78.441315,-0.047208])
twitter_stream.filter(track=['fortnite','pubg','ps5'])
# Out:
# SAVED('1490108620075319296', '1-7fd121e8f85daabfffba926199616aef')=>b'{"created_at":"Sat Feb 05 23:42:34 +0000 2022","id":1490108620075319296,"id_str":"1490108620075319296","text":"@Zoramar1 @AlbaCedeoZaval1 @BenAleur @GeovyJ @LilianaVelizLop @TedWaters1978 @LUNAGP11 @MelidaJumbo @DBernal_B\\u2026 https:\\/\\/t.co\\/bBKsHltf02","display_text_range":[117,140],"source":"\\u003ca href=\\"http:\\/\\/twitter.com\\/download\\/android\\" rel=\\"nofollow\\"\\u003eTwitter for Android\\u003c\\/a\\u003e","truncated":true,"in_reply_to_status_id":1490096634977570826,"in_reply_to_status_id_str":"1490096634977570826","in_reply_to_user_id":1043292042,"in_reply_to_user_id_str":"1043292042","in_reply_to_screen_name":"Zoramar1","user":{"id":1349566610160422914,"id_str":"1349566610160422914","name":"PATITA Paredes1971","screen_name":"PATITAParedes11","location":null,"url":null,"description":"SOY PATITA\\ud83c\\udf3a. BENDECIDA POR EL DON DE SER \\ud83d\\udc69\\u200d\\ud83d\\udc66MAM\\u00c1. MI VIDA CON MOMENTOS DE FELICIDAD. ALEGR\\u00cdA. AMOR\\u2764\\ufe0f. SONRISA. DIOS\\ud83d\\ude4f EL GRAN M\\u00c9DICO DE M\\u00c9DICOS\\ud83d\\ude4c","translator_type":"none","protected":false,"verified":false,"followers_count":324,"friends_count":1073,"listed_count":0,"favourites_count":19055,"statuses_count":4424,"created_at":"Thu Jan 14 04:00:26 +0000 2021","utc_offset":null,"time_zone":null,"geo_enabled":true,"lang":null,"contributors_enabled":false,"is_translator":false,"profile_background_color":"F5F8FA","profile_background_image_url":"","profile_background_image_url_https":"","profile_background_tile":false,"profile_link_color":"1DA1F2","profile_sidebar_border_color":"C0DEED","profile_sidebar_fill_color":"DDEEF6","profile_text_color":"333333","profile_use_background_image":true,"profile_image_url":"http:\\/\\/pbs.twimg.com\\/profile_images\\/1488661903601713152\\/2czAz0zd_normal.jpg","profile_image_url_https":"https:\\/\\/pbs.twimg.com\\/profile_images\\/1488661903601713152\\/2czAz0zd_normal.jpg","profile_banner_url":"https:\\/\\/pbs.twimg.com\\/profile_banners\\/1349566610160422914\\/1610599549","default_profile":true,"default_profile_image":false,"following":null,"follow_request_sent":null,"notifications":
utc_offset":null,"time_zone":null,"geo_enabled":true,"lang":null,"contributors_enabled":false,"is_translator":false,"profile_background_color":"F5F8FA","profile_background_image_url":"","profile_background_image_url_https":"","profile_background_tile":false,"profile_link_color":"1DA1F2","profile_sidebar_border_color":"C0DEED","profile_sidebar_fill_color":"DDEEF6","profile_text_color":"333333","profile_use_background_image":true,"profile_image_url":"http:\\/\\/pbs.twimg.com\\/profile_images\\/1460664978759991296\\/7cScpQsX_normal.jpg","profile_image_url_https":"https:\\/\\/pbs.twimg.com\\/profile_images\\/1460664978759991296\\/7cScpQsX_normal.jpg","profile_banner_url":"https:\\/\\/pbs.twimg.com\\/profile_banners\\/1204238356244291585\\/1636939287","default_profile":true,"default_profile_image":false,"following":null,"follow_request_sent":null,"notifications":null,"withheld_in_countries":[]},"geo":null,"coordinates":null,"place":{"id":"0177bc687a9ac697","url":"https:\\/\\/api.twitter.com\\/1.1\\/geo\\/id\\/0177bc687a9ac697.json","place_type":"city","name":"Quito","full_name":"Quito, Ecuador","country_code":"EC","country":"Ecuador","bounding_box":{"type":"Polygon","coordinates":[[[-78.948466,-0.588618],[-78.948466,0.255477],[-78.164897,0.255477],[-78.164897,-0.588618]]]},"attributes":{}},"contributors":null,"is_quote_status":false,"extended_tweet":{"full_text":"\\u2764\\ud83e\\udd32Juntos somos m\\u00e1s fuertes \\ud83c\\uddea\\ud83c\\udde8\\nAgradecemos a la Universidad Central del Ecuador @FacultadMedicinaUCE por su preocupaci\\u00f3n y ayuda a (LaComuna).\\n\\ud83e\\udd32Entrega de insumos m\\u00e9dicos para atenci\\u00f3n de heridos en la zona del siniestro.\\n#JhajairaUrrestaDDHH @ColectivoCc3 #TeamDerechosHumanos https:\\/\\/t.co\\/BLgB2ZmsxS","display_text_range":[0,276],"entities":{"hashtags":[{"text":"JhajairaUrrestaDDHH","indices":[221,241]},{"text":"TeamDerechosHumanos","indices":[256,276]}],"urls":[],"user_mentions":[{"screen_name":"ColectivoCc3","name":"colectivo comunidades creativas","id":1329792917934903297,"id_str":"1329792917934903297","indices":[242,255]}],"symbols":[],"media":[{"id":1490109567396687879,"id_str":"1490109567396687879","indices":[277,300],"media_url":"http:\\/\\/pbs.twimg.com\\/media\\/FK3uwbEXMAcibzS.jpg","media_url_https":"https:\\/\\/pbs.twimg.com\\/media\\/FK3uwbEXMAcibzS.jpg","url":"https:\\/\\/t.co\\/BLgB2ZmsxS","display_url":"pic.twitter.com\\/BLgB2ZmsxS","expanded_url":"https:\\/\\/twitter.com\\/EGuzmanurresta\\/status\\/1490109579262316544\\/photo\\/1","type":"photo","sizes":{"thumb":{"w":150,"h":150,"resize":"crop"},"small":{"w":680,"h":322,"resize":"fit"},"medium":{"w":1200,"h":568,"resize":"fit"},"large":{"w":1600,"h":757,"resize ...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_8244/1372700349.py in <module>
# ----> 1 twitter_stream.filter(locations=[-78.619545,-0.365889,-78.441315,-0.047208])
#       2 twitter_stream.filter(track=['fortnite','pubg','ps5'])
#
# C:\analisis2021B\lib\site-packages\tweepy\streaming.py in filter(self, follow, track, locations, filter_level, languages, stall_warnings, threaded)
#     268                                           body=body)
#     269         else:
# --> 270             self._connect(method, endpoint, headers=headers, body=body)
#     271
#     272     def sample(self, *, languages=None, stall_warnings=False, threaded=False):
#
# C:\analisis2021B\lib\site-packages\tweepy\streaming.py in _connect(self, method, endpoint, params, headers, body)
#     127                                 break
#     128
# --> 129                             for line in resp.iter_lines(
#     130                                 chunk_size=self.chunk_size
#     131                             ):
#
# C:\analisis2021B\lib\site-packages\requests\models.py in iter_lines(self, chunk_size, decode_unicode, delimiter)
#     802         pending = None
#     803
# --> 804         for chunk in self.iter_content(chunk_size=chunk_size, decode_unicode=decode_unicode):
#     805
#     806             if pending is not None:
#
# C:\analisis2021B\lib\site-packages\requests\models.py in generate()
#     758             if hasattr(self.raw, 'stream'):
#     759                 try:
# --> 760                     for chunk in self.raw.stream(chunk_size, decode_content=True):
#     761                         yield chunk
#     762                 except ProtocolError as e:
#
# C:\analisis2021B\lib\site-packages\urllib3\response.py in stream(self, amt, decode_content)
#     570         """
#     571         if self.chunked and self.supports_chunked_reads():
# --> 572             for line in self.read_chunked(amt, decode_content=decode_content):
#     573                 yield line
#     574         else:
#
# C:\analisis2021B\lib\site-packages\urllib3\response.py in read_chunked(self, amt, decode_content)
#     762
#     763             while True:
# --> 764                 self._update_chunk_length()
#     765                 if self.chunk_left == 0:
#     766                     break
#
# C:\analisis2021B\lib\site-packages\urllib3\response.py in _update_chunk_length(self)
#     692         if self.chunk_left is not None:
#     693             return
# --> 694         line = self._fp.fp.readline()
#     695         line = line.split(b";", 1)[0]
#     696         try:
#
# C:\analisis2021B\lib\socket.py in readinto(self, b)
#     703         while True:
#     704             try:
# --> 705                 return self._sock.recv_into(b)
#     706             except timeout:
#     707                 self._timeout_occurred = True
#
# C:\analisis2021B\lib\ssl.py in recv_into(self, buffer, nbytes, flags)
#    1271                   "non-zero flags not allowed in calls to recv_into() on %s" %
#    1272                   self.__class__)
# -> 1273             return self.read(nbytes, buffer)
#    1274         else:
#    1275             return super().recv_into(buffer, nbytes, flags)
#
# C:\analisis2021B\lib\ssl.py in read(self, len, buffer)
#    1127         try:
#    1128             if buffer is not None:
# -> 1129                 return self._sslobj.read(len, buffer)
#    1130             else:
#    1131                 return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
##couch
couch= couchdb.Server ("http://adrian:adrian@127.0.0.1:5984")
## Mongo
CLIENT = MongoClient('mongodb://localhost:27017')

try:
    CLIENT.admin.command('ismaster')
    print('MongoDB connection: Success')
except ConnectionFailure as cf:
    print('MongoDB connection: failed', cf)
# Out:
# MongoDB connection: Success

# %%
DBS=couch['loc2']

# %%
dbc=CLIENT['locq2']
colect=dbc['test1']
dbc=CLIENT['almacenaje2']

# %%
for docid in DBS.view('_all_docs'):
        id=docid['id']
        doc=DBS[id]
        dato={
            'id': doc['id'],
            "_rev": doc["_rev"],
            "created_at": doc["created_at"],
            "id": doc["id"],
            "id_str": doc["id_str"],
            "text": doc["text"],
            #"display_text_range": doc["display_text_range"],
            "source": doc["source"],
            "truncated": doc["truncated"],
            "in_reply_to_status_id": doc["in_reply_to_status_id"],
            "in_reply_to_status_id_str": doc["in_reply_to_status_id_str"],
            "in_reply_to_user_id": doc["in_reply_to_user_id"],
            "in_reply_to_user_id_str": doc["in_reply_to_user_id_str"],
            "in_reply_to_screen_name":doc["in_reply_to_screen_name"],
            "user": doc["user"],
            "geo": doc["geo"],
            "coordinates": doc["coordinates"],
            "place":doc["place"],
            "contributors": doc["contributors"],
            "is_quote_status":doc["is_quote_status"],
            "quote_count": doc["quote_count"],
            "reply_count": doc["reply_count"],
            "retweet_count":doc["retweet_count"],
            "favorite_count": doc["favorite_count"],
            "entities":doc["entities"],
            "favorited": doc["favorited"],
            "retweeted": doc["retweeted"],
            "filter_level": doc["filter_level"],
            "lang": doc["lang"],
            "timestamp_ms": doc["timestamp_ms"]
              
        }
        colect.insert_one(dato)
